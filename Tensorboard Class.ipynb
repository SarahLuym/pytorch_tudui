# %% [markdown]
# # Set up Code

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded the assignment
# Example: If you create a 2020FA folder and put all the files under A1 folder, then '2020FA/A1'
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'pytorch_tudui'
GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['.DS_Store', '.git', 'Data', 'Dataset Class.ipynb', 'Tensorboard Class.ipynb']

# %%
import sys
sys.path.append(GOOGLE_DRIVE_PATH)

import time, os
os.environ["TZ"] = "US/Eastern"
time.tzset()

# %%
import torch
if torch.cuda.is_available:
  print('Good to go!')
else:
  print('Please set GPU via Edit -> Notebook Settings.')
# Out:
# Good to go!

# %% [markdown]
# # Create a TensorBoard Class!

# %%
from torch.utils.tensorboard import SummaryWriter
import numpy as np
from PIL import Image

# %%
writer = SummaryWriter("logs")
image_path = '/content/drive/MyDrive/pytorch_tudui/Data/tutorial_data/train/ants_image/6240329_72c01e663e.jpg'
img_PIL = Image.open(image_path)
img_array = np.array(img_PIL)
print(type(img_array))
print(img_array.shape)
# Out:
# <class 'numpy.ndarray'>
# (369, 500, 3)

# %%
writer.add_image("train", img_array, 1, dataformats='HWC')
for i in range(100):
  writer.add_scalar("y=2x", 3*i, i)

# %%
writer.close()
